# %% [markdown]
# ### Optimal information transfer and collective decision making in Ant colonies

# %% [markdown]
# #### Optimal Noise level exists and depends upon the rate of change in the environment

# %%
# %matplotlib inline
import sys
sys.path.append('../')
import agent_based_model_for_any_number_of_choices as agentm
import system_dynamics_using_sdeint as systemd
import numpy as np

# %% [markdown]
# ##### Page 5 section 3
# k =  0,
# n =  large,
# deposit ratio q1/q2 =  high
#
# two stable points will be observed and they will not change if the
# environmrnt changes

# %%
steps = 100    # we want the model to run for 200 steps
rotation_step = 100 # utility should be inverted at this step
flag = False # utility inversion is off
noise_flag = False
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0, alpha = 2,
                                   utility_of_choices= [0.005, 1.0], initial_experiences=[1.0, 3.0],
                                   discount_rate=0.9, noise_standard_deviation=0)

d.run(steps,rotation_step, flag, noise_flag)
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule            6.00000
# option 1 has area under the curve as:
# using composite trapezoidal rule         9894.00000

# %% [markdown]
# In a dynamic environment a change in utility has no effect on the behaviours of ants

# %%
steps = 100    # we want the model to run for 200 steps
rotation_step = 50 # utility should be inverted at this step
flag = True # utility inversion is off
noise_flag = False
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0, alpha = 2,
                                   utility_of_choices= [0.005, 1.0], initial_experiences=[1.0, 3.0],
                                   discount_rate=0.9, noise_standard_deviation=0)

d.run(steps,rotation_step, flag, noise_flag)
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule            9.00000
# option 1 has area under the curve as:
# using composite trapezoidal rule         9891.00000

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=0,
                                    alpha=2,
                                    utility_of_choices=[0.005, 1.0],
                                    initial_experiences=[1.0, 3.0],
                                    discount_rate=0.9,
                                    sd=0,
                                    rotation_time=200,
                                    flag=False)

time_vector=np.linspace(0, 100, 50)
sysd.solve(time_vector)

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=0,
                                    alpha=2,
                                    utility_of_choices=[0.005, 1.0],
                                    initial_experiences=[1.0, 3.0],
                                    discount_rate=0.9,
                                    sd=0,
                                    rotation_time=50,
                                    flag=True)

time_vector=np.linspace(0, 100, 50)
sysd.solve(time_vector)

# %% [markdown]
# ### Parameters as given by section 4.1
#
# k = 1,
# p = 0.05,
# q1 = 1.5,
# q2 = 3

# %%
steps = 100    # we want the model to run for 200 steps
rotation_step = 20 # utility should be inverted at this step
flag = True # utility inversion is off
noise_flag = True
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 1, alpha = 2,
                                   utility_of_choices= [1.5, 3.0], initial_experiences=[0.001, 0.003],
                                   discount_rate=0.95, noise_standard_deviation=0.05)

d.run(steps,rotation_step, flag, noise_flag)
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule           52.00000
# option 1 has area under the curve as:
# using composite trapezoidal rule         9848.00000

# %%
steps = 100    # we want the model to run for 200 steps
rotation_step = 20 # utility should be inverted at this step
flag = True # utility inversion is off
noise_flag = True
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 1, alpha = 2,
                                   utility_of_choices= [1.5, 3.0], initial_experiences=[0.001, 0.003],
                                   discount_rate=0.95, noise_standard_deviation=7.5)

d.run(steps,rotation_step, flag, noise_flag)
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule           53.00000
# option 1 has area under the curve as:
# using composite trapezoidal rule         9847.00000

# %%
steps = 100    # we want the model to run for 200 steps
rotation_step = 20 # utility should be inverted at this step
flag = True # utility inversion is off
noise_flag = True
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 1, alpha = 2,
                                   utility_of_choices= [1.5, 3.0], initial_experiences=[0.001, 0.003],
                                   discount_rate=0.95, noise_standard_deviation=20.0)

d.run(steps,rotation_step, flag, noise_flag)
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule         3004.00000
# option 1 has area under the curve as:
# using composite trapezoidal rule         6896.00000

# %%
steps = 100    # we want the model to run for 200 steps
rotation_step = 20 # utility should be inverted at this step
flag = True # utility inversion is off
noise_flag = True
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 1, alpha = 2,
                                   utility_of_choices= [1.5, 3.0], initial_experiences=[0.001, 0.003],
                                   discount_rate=0.95, noise_standard_deviation=50.0)

d.run(steps,rotation_step, flag, noise_flag)
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule         3428.00000
# option 1 has area under the curve as:
# using composite trapezoidal rule         6472.00000

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[1.5, 3.0],
                                    initial_experiences=[0.001, 0.003],
                                    discount_rate=0.95,
                                    sd=0.05,
                                    rotation_time=20,
                                    flag=True)

time_vector=np.linspace(0, 100, 50)
sysd.solve(time_vector)

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[1.5, 3.0],
                                    initial_experiences=[0.001, 0.003],
                                    discount_rate=0.95,
                                    sd=7.5,
                                    rotation_time=20,
                                    flag=True)

time_vector=np.linspace(0, 100, 50)
sysd.solve(time_vector)

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[1.5, 3.0],
                                    initial_experiences=[0.001, 0.003],
                                    discount_rate=0.95,
                                    sd=20,
                                    rotation_time=20,
                                    flag=True)

time_vector=np.linspace(0, 100, 50)
sysd.solve(time_vector)

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[1.5, 3.0],
                                    initial_experiences=[0.001, 0.003],
                                    discount_rate=0.95,
                                    sd=50,
                                    rotation_time=20,
                                    flag=True)

time_vector=np.linspace(0, 100, 50)
sysd.solve(time_vector)

# %% [markdown]
# # How much noise is too much noise

# %%
import stat_gen_sys_dynamic as sgsd

# %%
sdg = sgsd.SystemDynamicsStatGenerator(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[1.5, 3.0],
                                    initial_experiences=[0.001, 0.003],
                                    discount_rate=0.95,
                                    step=0.1,
                                    end_sd=500,
                                    rotation_time=20,
                                    flag=True)

sdg.generate_utility_sweep(time_vector = np.linspace(0, 1000, 500))

# %% [markdown]
# Somewhere around 50, Utility is the highest

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[1.5, 3.0],
                                    initial_experiences=[0.001, 0.003],
                                    discount_rate=0.95,
                                    sd=45,
                                    rotation_time=20,
                                    flag=True)

time_vector=np.linspace(0, 200, 100)
sysd.solve(time_vector)
