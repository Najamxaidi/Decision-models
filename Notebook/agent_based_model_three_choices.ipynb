# %% [markdown]
# Lets now extend the model for three choices

# %% [markdown]
# # Simple scnerio -- no rotation

# %%
# %pylab inline
# %matplotlib inline

# %%
import sys
sys.path.append('../')

# %%
import agent_based_model_for_any_number_of_choices as agentm

# %%
steps = 200    # we want the model to run for 200 steps
rotation_step = 100 # utility should be inverted at this step
flag = False # utility inversion is off

# %%
#simple case - no noise - large difference in experiences
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [10, 100, 20], initial_experiences=[200, 2, 50],
                                   discount_rate=0.01, noise_standard_deviation=0.1)

d.run(steps,rotation_step, flag)

# %%
#simple case - with noise - large difference in experiences
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [10, 100, 20], initial_experiences=[200, 2, 50],
                                   discount_rate=0.01, noise_standard_deviation=50)

d.run(steps,rotation_step, flag)

# %% [markdown]
# When there is noise in the system, agents tend to explore more of their surrounding

# %% [markdown]
# # Less difference in initial experinces Scenario

# %%
#simple case - no noise - small difference in experiences
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [10, 100, 20], initial_experiences=[100, 2, 50],
                                   discount_rate=0.01, noise_standard_deviation=0.1)

d.run(steps,rotation_step, flag)

# %% [markdown]
# agents prefer choice number 2 which neither has high utility nor high initial experience

# %%
# noise will help them over here as well
flag = False
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [10, 100, 20], initial_experiences=[100, 2, 50],
                                   discount_rate=0.01, noise_standard_deviation=100)

d.run(steps,rotation_step, flag)

# %% [markdown]
# # Rotation

# %%
# lets turn on rotation
flag = True # utility inversion is off

# %%
#simple case - no noise - large difference in experiences
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [10, 100, 20], initial_experiences=[200, 2, 50],
                                   discount_rate=0.01, noise_standard_deviation=0.1)

d.run(steps,rotation_step, flag)

# %%
#simple case - with noise - large difference in experiences
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [10, 100, 20], initial_experiences=[200, 2, 50],
                                   discount_rate=0.01, noise_standard_deviation=50)

d.run(steps,rotation_step, flag)

# %%
#simple case - no noise - small difference in experiences
#OBSERVE CHANGE IN UTILITIES AND EXPERIENCES FOR BETTER RESULTS
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [100, 10, 50], initial_experiences=[100, 2, 80],
                                   discount_rate=0.01, noise_standard_deviation=0.1)

d.run(steps,rotation_step, flag)

# %% [markdown]
# initially choice 0 is chisen because of its high utility and experience. But once the utility has been rotated agents still prefer choice 0

# %%
#Lets see if noise helps in this scnerio
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                   utility_of_choices= [100, 10, 50], initial_experiences=[100, 2, 80],
                                   discount_rate=0.01, noise_standard_deviation=500)

d.run(steps,rotation_step, flag)

# %% [markdown]
# # Noise indeed helps in choosing the right option
