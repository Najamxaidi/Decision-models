# %% [markdown]
# This paper replicate the results as presented by S. C. NICOLIS AND J. L. DENEUBOURG In their paper Emerging Patterns and Food Recruitment in Ants: an Analytical Study

# %%
# lets setup the system dynamic model first

# %pylab inline
# %matplotlib inline

import sys
import numpy as np
sys.path.append('../')

import system_dynamics_using_sdeint as systemd

# %% [markdown]
# #  16 choices scneario
# ## System dynamices model
# ### No noise

# %% [markdown]
# In the scnerios below phi would be varied in each case to move the system between three possible regions og the grpah

# %% [markdown]
# ### Explotation of the multiple choices

# %% [markdown]
# To get (phi * q)/2 in this area phi = 8 has been used it gives a value (phi * q)/2 = 2

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=8, k=1, alpha=2,
                                    utility_of_choices=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                                    initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 0.16, 
                                                         0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23, 0.24, 0.25, 0.10],
                                    discount_rate=0.9, sd=0, rotation_time=2000, flag=False)

sysd.solve(time_vector=np.linspace(0, 100, 50))
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule           12.86197
# option 1 has area under the curve as:
# using composite trapezoidal rule           12.89201
# option 2 has area under the curve as:
# using composite trapezoidal rule           12.90701
# option 3 has area under the curve as:
# using composite trapezoidal rule           12.92201
# option 4 has area under the curve as:
# using composite trapezoidal rule           12.93699
# option 5 has area under the curve as:
# using composite trapezoidal rule           12.95197
# option 6 has area under the curve as:
# using composite trapezoidal rule           12.96694
# option 7 has area under the curve as:
# using composite trapezoidal rule           12.98190
# option 8 has area under the curve as:
# using composite trapezoidal rule           12.99686
# option 9 has area under the curve as:
# using composite trapezoidal rule           13.01180
# option 10 has area under the curve as:
# ...

# %% [markdown]
# An equal exploitation of multiple sources can be observed. PLEASE LOOK AT THE AREA UNDER THE CURVE THAT INDICATES EQUAL EXPLOTATION

# %% [markdown]
# ### Explotitation of a single or of a multiple source

# %% [markdown]
# To get (phi * q)/2 in this area phi = 40 has been used it gives a value (phi * q)/2 = 10

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=40, k=1, alpha=2,
                                    utility_of_choices=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                                    initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 0.16, 
                                                         0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23, 0.24, 0.25, 0.10],
                                    discount_rate=0.9, sd=0, rotation_time=2000, flag=False)

sysd.solve(time_vector=np.linspace(0, 100, 50))
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule            3.69891
# option 1 has area under the curve as:
# using composite trapezoidal rule            3.93415
# option 2 has area under the curve as:
# using composite trapezoidal rule            4.07216
# option 3 has area under the curve as:
# using composite trapezoidal rule            4.22664
# option 4 has area under the curve as:
# using composite trapezoidal rule            4.40068
# option 5 has area under the curve as:
# using composite trapezoidal rule            4.59926
# option 6 has area under the curve as:
# using composite trapezoidal rule            4.82996
# option 7 has area under the curve as:
# using composite trapezoidal rule            5.10862
# option 8 has area under the curve as:
# using composite trapezoidal rule            5.45022
# option 9 has area under the curve as:
# using composite trapezoidal rule            5.89194
# option 10 has area under the curve as:
# ...

# %% [markdown]
# An explotation of multiple resources can be observed

# %% [markdown]
# Setting phi to 64 still keep us in "explotation of multiple or single source area"

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=64, k=1, alpha=2,
                                    utility_of_choices=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                                    initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 0.16, 
                                                         0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23, 0.24, 0.25, 0.10],
                                    discount_rate=0.9, sd=0, rotation_time=2000, flag=False)

sysd.solve(time_vector=np.linspace(0, 100, 50))
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule            1.38803
# option 1 has area under the curve as:
# using composite trapezoidal rule            1.59551
# option 2 has area under the curve as:
# using composite trapezoidal rule            1.71587
# option 3 has area under the curve as:
# using composite trapezoidal rule            1.85018
# option 4 has area under the curve as:
# using composite trapezoidal rule            2.00136
# option 5 has area under the curve as:
# using composite trapezoidal rule            2.19074
# option 6 has area under the curve as:
# using composite trapezoidal rule            2.42262
# option 7 has area under the curve as:
# using composite trapezoidal rule            2.70002
# option 8 has area under the curve as:
# using composite trapezoidal rule            3.04155
# option 9 has area under the curve as:
# using composite trapezoidal rule            3.51898
# option 10 has area under the curve as:
# ...

# %% [markdown]
# ### Exploitation of single source

# %% [markdown]
# Setting phi to 100 gives a value of 25 for  (phi *q)/2 bring us in the area of exploitation of single resource

# %%
sysd = systemd.SystemDynamicsWithSdeint(number_of_agents=100, k=1, alpha=2,
                                    utility_of_choices=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                                    initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 0.16, 
                                                         0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23, 0.24, 0.25, 0.10],
                                    discount_rate=0.9, sd=0, rotation_time=2000, flag=False)

sysd.solve(time_vector=np.linspace(0, 100, 50))
# Out:
# option 0 has area under the curve as:
# using composite trapezoidal rule            0.75483
# option 1 has area under the curve as:
# using composite trapezoidal rule            0.97879
# option 2 has area under the curve as:
# using composite trapezoidal rule            1.10941
# option 3 has area under the curve as:
# using composite trapezoidal rule            1.25491
# option 4 has area under the curve as:
# using composite trapezoidal rule            1.41747
# option 5 has area under the curve as:
# using composite trapezoidal rule            1.59968
# option 6 has area under the curve as:
# using composite trapezoidal rule            1.80459
# option 7 has area under the curve as:
# using composite trapezoidal rule            2.03580
# option 8 has area under the curve as:
# using composite trapezoidal rule            2.41887
# option 9 has area under the curve as:
# using composite trapezoidal rule            3.04386
# option 10 has area under the curve as:
# ...

# %% [markdown]
# # Agent based model
# ## without noise

# %%
import agent_based_model_for_any_number_of_choices as agentm

# %%
steps = 50
rotation_step = 50
flag = False   # rotation flag
noise_flag = False

# %% [markdown]
# ## Observe exploitation of multiple sources

# %%
d = agentm.Agent_Based_Decision_Model(number_of_agents= 8, k = 0.5, alpha = 2,
                                       utility_of_choices= [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                            0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
                                              0.5], 
                                       initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 
                                                            0.16, 0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23,
                                               0.24, 0.25, 0.10],
                                       discount_rate=1, 
                                       noise_standard_deviation=0)

d.run(steps,rotation_step, flag, noise_flag)

# %% [markdown]
# ## Observe explotation of multiple or a single resource

# %%
d = agentm.Agent_Based_Decision_Model(number_of_agents= 10, k = 0.5, alpha = 2,
                                       utility_of_choices= [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                            0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
                                              0.5], 
                                       initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 
                                                            0.16, 0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23,
                                               0.24, 0.25, 0.10],
                                       discount_rate=1, 
                                       noise_standard_deviation=0)

d.run(steps,rotation_step, flag, noise_flag)

# %%
d = agentm.Agent_Based_Decision_Model(number_of_agents= 64, k = 0.5, alpha = 2,
                                       utility_of_choices= [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                            0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
                                              0.5], 
                                       initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 
                                                            0.16, 0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23,
                                               0.24, 0.25, 0.10],
                                       discount_rate=1, 
                                       noise_standard_deviation=0)

d.run(steps,rotation_step, flag, noise_flag)

# %% [markdown]
# ## Observe Explotation of a single resource

# %%
d = agentm.Agent_Based_Decision_Model(number_of_agents= 100, k = 0.5, alpha = 2,
                                       utility_of_choices= [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 
                                                            0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
                                              0.5], 
                                       initial_experiences=[0.10, 0.12, 0.13, 0.14, 0.15, 
                                                            0.16, 0.17, 0.18, 0.19, 0.20, 0.21, 0.22, 0.23,
                                               0.24, 0.25, 0.10],
                                       discount_rate=1, 
                                       noise_standard_deviation=0)

d.run(steps,rotation_step, flag, noise_flag)
