# %%
# %pylab inline
# %matplotlib inline

import sys
import numpy as np
sys.path.append('../')

import agent_based_model_for_any_number_of_choices as agentb
import stat_gen_agent_based as agab

# %%
steps = 1000
rotation_step = 200
flag = True
noise_flag = True
d = agentb.Agent_Based_Decision_Model(number_of_agents= 10, k = 1, alpha = 2,
                                utility_of_choices= [0.25,0.50,0.75,1],
                                initial_experiences=[1, 0.75, 0.50, 0.25],
                                discount_rate=0.99, noise_standard_deviation=0.5)

d.run(steps,rotation_step, flag, noise_flag, plotting=True)

# %%
steps = 1000
rotation_step = 200
flag = True
noise_flag = True
d = agentb.Agent_Based_Decision_Model(number_of_agents= 10, k = 1, alpha = 2,
                                utility_of_choices= [0.25,0.50,0.75,1],
                                initial_experiences=[1, 0.75, 0.50, 0.25],
                                discount_rate=0.99, noise_standard_deviation=1.3)

d.run(steps,rotation_step, flag, noise_flag, plotting=True)

# %%
steps = 1000
rotation_step = 200
flag = True
noise_flag = True
d = agentb.Agent_Based_Decision_Model(number_of_agents= 10, k = 1, alpha = 2,
                                utility_of_choices= [0.25,0.50,0.75,1],
                                initial_experiences=[1, 0.75, 0.50, 0.25],
                                discount_rate=0.99, noise_standard_deviation=4)

d.run(steps,rotation_step, flag, noise_flag, plotting=True)

# %%
absg = agab.AgentBasedStatGenerator(number_of_agents=10,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[0.25,0.50,0.75,1],
                                    initial_experiences=[1, 0.75, 0.50, 0.25],
                                    discount_rate=0.99,
                                    step_for_sd=0.5,
                                    end_sd=50)


steps = 1000
rotation_step = 200

absg.generate_utility_sweep(steps,rotation_step)

# %% [markdown]
# ## Another random test

# %%
steps = 1000
rotation_step = 200
flag = True
noise_flag = True
d = agentb.Agent_Based_Decision_Model(number_of_agents= 100, k = 1, alpha = 2,
                                   utility_of_choices= [0.25,0.50,0.75,1],
                                   initial_experiences=[0.001, 0.001, 0.001, 0.001],
                                   discount_rate=1, noise_standard_deviation=0.1)

d.run(steps,rotation_step, flag, noise_flag, plotting=True)

# %%
absg = agab.AgentBasedStatGenerator(number_of_agents=100,
                                    k=1,
                                    alpha=2,
                                    utility_of_choices=[0.25,0.50,0.75,1],
                                    initial_experiences=[0.001, 0.001, 0.001, 0.001],
                                    discount_rate=0.95,
                                    step_for_sd=0.5,
                                    end_sd=100)


steps = 1000
rotation_step = 200

absg.generate_utility_sweep(steps,rotation_step)

# %%
steps = 1000
rotation_step = 200
flag = True
noise_flag = True
d = agentb.Agent_Based_Decision_Model(number_of_agents= 100, k = 1, alpha = 2,
                                   utility_of_choices= [0.25,0.50,0.75,1],
                                   initial_experiences=[0.001, 0.001, 0.001, 0.001],
                                   discount_rate=1, noise_standard_deviation=16)

d.run(steps,rotation_step, flag, noise_flag, plotting=True)
